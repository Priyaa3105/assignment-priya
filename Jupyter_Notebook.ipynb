# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystems
# In this notebook, Data Science Tools and Ecosystems are summarized.
#
# Some of the important languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Julia
# 4. SQL
#
# Some of the commonly used libraries used by Data Scientists are:
# 1. Numpy
# 2. Keras
# 3. Pandas
# 4. PyTorch
#
#
# | Data Science tools |
# |--------------------|
# |tensorflow |
# |Apache Hadoop|
# |Tableau |
#
# ### Below are a few examples of evaluating arithematic expressions in python
#
# This is a simple arithematic expression to first multiply and then add integers-

# %%
(3*4)+5
# Out:
# [1] 17

# %%
print("This will convert 200 minutes into hours by dividing by 60")

print(200/60)
# Out:
# [1] "This will convert 200 minutes into hours by dividing by 60"
# [1] 3.333333

# %% [markdown]
# # **Objectives**
#
# - To summarize the tools used in Data Science
# - To summarize the libraries used by Data Scientists
# - To perform arithematic expressions in Jupyter Notebooks
# - To Summarize various operations in Jupyter Notebooks
#
# ## Author
# Priya
